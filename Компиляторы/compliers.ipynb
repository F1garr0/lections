# %% [markdown]
# #### Компиляторы лекция №2

# %% [markdown]
# | регистры | Предназначение                | размер   | количество |
# |:--------:|:-----------------------------:|:--------:|:----------:|
# | GR       | целочисленные регистры        | (64бита) | (128 шт)   |
# | FR       | регистры с плавающей запятой  | (82бита) | (128 шт)   |
# | PR       | предикатные регистры          | (1бит)   | (64шт)     |
# | AR       | прикладные регисты            | (64)     | (128)      |
# | BR       | регистры ветвления            | (64)     | (8)        |
# | IP       | счетчик команд                | (64)     | (1)        |
# | CSM      | окно регистров                | ()       | (1)        |
# | CPVID    |          хз                   | (64)     | (4-5)      |
# | CFM      | состояние регистрового окна   | (38)     | (1)        |
#
# r0-31 - статические реисты
# r32-127 - вращающиеся
#
# r0=0
# r1=gp
# к4-7 состояние программы
# r12 регистр стека(sp)
# r14-31 регистр переноса(временного хранения)
#
# f0-31 статические
# f2-5 состояние процесса
# f6-7 временного хранения
# f8-15 хуй пойми что
# f16-31 хуй пойми что[2]
#
# предикатные регистры
# p0-16 статические
# p0 = 1
# p1-5 сохраняется информация о процессе
# p6-15 регистр временного хранения
#
#
# ветвление
# b0 возврат из программы
# b1-5 информация о процессе
# b6-7
#
# ar

# %% [markdown]
# do I-1,N
#     IND(i)=JND(i)+K
# endo do
#
# ------------------------
#
# r5 - I
# r7 - K
# r6 - IND
# r8 - IND
#
# -----без вращающихся регистров----------
#
# L: ld ld8 r8=[r5],8
# add r9=r8,r7
# st8 [r6]=r9,8
# br.cloop L
